# %% [markdown]
# # PotHole

# %% [markdown]
# Importing Libraries

# %%
# K-Means Clustering

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Loading the train and test dataset

# %%
# Importing the dataset
train = pd.read_csv('sensor.csv')
#X = dataset.iloc[:, [3, 4]].values
# y = dataset.iloc[:, 3].values

# %% [markdown]
# # Exploring the dataset

# %%
print("Training Dataset Shape:")
print(train.shape)
print("\n")
print("Training Dataset Columns/Features:")
print(train.dtypes)
# Out:
# Training Dataset Shape:
# (2191, 7)
#
#
# Training Dataset Columns/Features:
# Longitude    float64
# Latitude     float64
# Time         float64
# X            float64
# Y            float64
# Z            float64
# Speed        float64
# dtype: object

# %%
#Viewing the top few entries of Training Dataset
train.head()
# Out:
#    Longitude  Latitude   Time        X        Y         Z   Speed
# 0     4.6667    4.3333  0.017  0.64604 -0.18366  0.062945  1.0105
# 1    22.0000    6.0000  0.080  0.65075 -0.18196  0.054462  1.0105
# 2    15.6670   17.3330  0.143  0.65000 -0.17978  0.052816  1.0105
# 3    25.6670   16.3330  0.207  0.65084 -0.18210  0.050718  1.0105
# 4    13.3330    5.0000  0.269  0.64980 -0.18300  0.049373  1.0105

# %%
#Let’s make a copy of train and test data so that even if we have to make any changes in these datasets we would 
#not lose the original datasets.
train_original=train.copy()

# %%
train.describe()
# Out:
#          Longitude     Latitude         Time            X            Y  \
# count  2191.000000  2191.000000  2191.000000  2191.000000  2191.000000
# mean     13.373646    13.443019    68.916319     0.667547    -0.253094
# std       7.642065     7.690853    39.830790     0.143055     0.062594
# min       0.333330     0.333330     0.017000     0.150770    -0.575960
# 25%       7.000000     6.666700    34.442000     0.581350    -0.275995
# 50%      13.333000    13.667000    68.862000     0.678660    -0.244440
# 75%      20.000000    20.166500   103.380000     0.747260    -0.223235
# max      26.667000    26.667000   137.910000     1.091400    -0.015867
#
#                  Z        Speed
# count  2191.000000  2191.000000
# mean     -0.097941     0.999090
# std       0.121646     0.327069
# min      -0.665670     0.526320
# 25%      -0.155575     0.694740
# 50%      -0.084326     0.968420
# 75%      -0.006989     1.242100
# max       0.161490     1.684200

# %%
X = train.iloc[:, [2,3,4,5,6]].values

# %%
X
# Out:
# array([[ 1.7000e-02,  6.4604e-01, -1.8366e-01,  6.2945e-02,  1.0105e+00],
#        [ 8.0000e-02,  6.5075e-01, -1.8196e-01,  5.4462e-02,  1.0105e+00],
#        [ 1.4300e-01,  6.5000e-01, -1.7978e-01,  5.2816e-02,  1.0105e+00],
#        ...,
#        [ 1.3778e+02,  8.1961e-01, -3.0433e-01, -3.8240e-01,  8.8421e-01],
#        [ 1.3784e+02,  8.1637e-01, -2.9906e-01, -3.7946e-01,  1.0000e+00],
#        [ 1.3791e+02,  8.2975e-01, -2.9361e-01, -3.9194e-01,  1.0000e+00]])

# %%
# Splitting the dataset into the Training set and Test set
#from sklearn.cross_validation import train_test_split
#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)"""
# Out:
# 'from sklearn.preprocessing import StandardScaler\nsc_X = StandardScaler()\nX_train = sc_X.fit_transform(X_train)\nX_test = sc_X.transform(X_test)\nsc_y = StandardScaler()\ny_train = sc_y.fit_transform(y_train)'

# %%
# X Column is the actual axis about which major decision will occur as it is giving us the sensor value for GYROSCOPE 
# through which we are able to detect whether there is any pothole or not ????

# %%
train.isnull().sum()
# Out:
# Longitude    0
# Latitude     0
# Time         0
# X            0
# Y            0
# Z            0
# Speed        0
# dtype: int64

# %%
#plot
plt.figure(figsize=(16,8))
plt.plot(train['X'], label='X coordinates displacement')
plt.title('Gyroscope Measures')
plt.ylabel('X coord')
plt.xlabel('datapoints')
plt.grid(True)

# %% [markdown]
# Now here i have to use data point for pothole hit

# %%
discreteArray = train.iloc[:, [3]].values # X values
mean_of_X=sum(discreteArray)/len(dicreteArray)
#discreteArray=discreteArray-mean_of_X
print(discreteArray)



#mean_of_X

# max_x = max(discreteArray)

#max_x

# t = (mean_of_X + max_x)/2

#t
#temp=0
#for i in range(len(dicreteArray)):
#    if(dicreteArray[i]>=t):
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-fe0d8344f8e4> in <module>
#       1 discreteArray = train.iloc[:, [3]].values # X values
# ----> 2 mean_of_X=sum(discreteArray)/len(dicreteArray)
#       3 #discreteArray=discreteArray-mean_of_X
#       4 print(discreteArray)
#       5
#
# NameError: name 'dicreteArray' is not defined

# %%
#plot
plt.figure(figsize=(16,8))
plt.plot(discreteArray, label='X coordinates displacement')
plt.title('Gyroscope Measures')
plt.ylabel('X coord')
plt.xlabel('datapoints')
plt.grid(True)

# %%
#mean_of_X

max_x1 = max(discreteArray)

#max_x

t1 = (mean_of_X + max_x1)/2

#t
#temp=0
#for i in range(len(dicreteArray)):
#    if(dicreteArray[i]>=t):
print(t1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-38eb26374e82> in <module>
#       5 #max_x
#       6
# ----> 7 t1 = (mean_of_X + max_x1)/2
#       8
#       9 #t
#
# NameError: name 'mean_of_X' is not defined

# %%
dicreteArray = np.array(train.iloc[:, [3]].squeeze())

# %%
from scipy import signal
import matplotlib.pyplot as plt

discreteArray = train.X
loc,_ = signal.find_peaks(discreteArray,height=0.8)
b = np.multiply(discreteArray,-1)
b = np.subtract(b,np.mean(b))
tt = (max(b)-np.mean(b))/2
loc1,_ = signal.find_peaks(b,height=tt)

plt.plot(discreteArray)
plt.plot(loc, discreteArray[loc], "x")
plt.plot(loc1, discreteArray[loc1], "x")
plt.plot(np.zeros_like(k), "--", color="gray")
plt.show()
plt.legend()

plt.title('POTHOLE_HIT')
plt.xlabel('datapoints')
plt.ylabel('dispacement from base level')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-0f6f3a840b04> in <module>
#      12 plt.plot(loc, discreteArray[loc], "x")
#      13 plt.plot(loc1, discreteArray[loc1], "x")
# ---> 14 plt.plot(np.zeros_like(k), "--", color="gray")
#      15 plt.show()
#      16 plt.legend()
#
# NameError: name 'k' is not defined

# %%
lat = train.Latitude
lon = train.Longitude
result_csv=[]
for i in loc1:
    result_csv.append([lat[i],lon[i]])
result_csv



np.savetxt("out.csv",result_csv,delimiter=',')

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------------
